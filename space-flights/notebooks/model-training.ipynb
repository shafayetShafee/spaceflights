# %%
# %load_ext kedro.ipython
# Out:
# The kedro.ipython extension is already loaded. To reload it, use:
#   %reload_ext kedro.ipython

# %%
df = catalog.load("model_input_table")
df.head()
# Out:
# [07/12/24 05:07:49] INFO     Loading data from model_input_table (CSVDataset)...                ]8;id=812897;file:///Users/ovee/Documents/kedro-project/spaceflights/.venv/lib/python3.9/site-packages/kedro/io/data_catalog.py\data_catalog.py]8;;\:]8;id=539695;file:///Users/ovee/Documents/kedro-project/spaceflights/.venv/lib/python3.9/site-packages/kedro/io/data_catalog.py#508\508]8;;\
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#    shuttle_id       shuttle_location shuttle_type engine_type  \
# 0       45163  Sao Tome and Principe      Type V5      Plasma
# 1       49438      Wallis and Futuna      Type V2      Plasma
# 2       10750                   Niue      Type F5     Quantum
# 3        4146                  Malta      Type V2     Quantum
# 4        5067                  Malta      Type V2      Plasma
#
#         engine_vendor  engines  passenger_capacity cancellation_policy  crew  \
# 0  ThetaBase Services      2.0                   4            moderate   2.0
# 1  ThetaBase Services      3.0                   5            moderate   3.0
# 2  ThetaBase Services      1.0                   2              strict   1.0
# 3  ThetaBase Services      1.0                   2            moderate   1.0
# 4  ThetaBase Services      5.0                  10              strict   5.0
#
#    d_check_complete  ...  review_scores_crew  review_scores_location  \
# 0             False  ...                 9.0                     9.0
# 1             False  ...                10.0                    10.0
# 2              True  ...                10.0                    10.0
# 3             False  ...                10.0                     9.0
# 4             False  ...                10.0                     9.0
#
#    review_scores_price  number_of_reviews  reviews_per_month     id  \
# 0                  9.0                 26               0.77  32413
# 1                  9.0                 61               0.62  14122
# 2                 10.0                467               4.66  47761
# 3                  9.0                318               3.22  26648
# 4                 10.0                 22               0.29  26648
#
#    company_rating  company_location  total_fleet_count  iata_approved
# 0           100.0     Faroe Islands                1.0          False
# 1           100.0             Malta                1.0           True
# 2           100.0              Niue                2.0          False
# 3           100.0              Niue                2.0           True
# 4           100.0              Niue                2.0           True
#
# [5 rows x 27 columns]

# %%
from sklearn.model_selection import train_test_split

# %%
features = [
    "engines",
    "passenger_capacity",
    "crew",
    "d_check_complete",
    "moon_clearance_complete",
    "iata_approved",
    "company_rating",
    "review_scores_rating"
]

# %%
X = df[features]
y = df["price"]

# %%
X.head()
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#    engines  passenger_capacity  crew  d_check_complete  \
# 0      2.0                   4   2.0             False
# 1      3.0                   5   3.0             False
# 2      1.0                   2   1.0              True
# 3      1.0                   2   1.0             False
# 4      5.0                  10   5.0             False
#
#    moon_clearance_complete  iata_approved  company_rating  \
# 0                    False          False           100.0
# 1                    False           True           100.0
# 2                    False          False           100.0
# 3                    False           True           100.0
# 4                    False           True           100.0
#
#    review_scores_rating
# 0                  91.0
# 1                  96.0
# 2                  97.0
# 3                  95.0
# 4                  97.0

# %%
y.head()
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# 0    1715.0
# 1    3405.0
# 2    1806.0
# 3    1676.0
# 4    4718.0
# Name: price, dtype: float64

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
from sklearn.linear_model import LinearRegression

# %%
model = LinearRegression()
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
from sklearn.metrics import r2_score

# %%
y_pred = model.predict(X_test)
r2_score(y_test, y_pred)
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# 0.41625187810898845
